# %% [markdown]
# ## EA Pipeline Skeleton

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import datetime
import random
import sys
import os
import glob
import csv

# %% [markdown]
# ### PlaneModel defines a set of useful classes

# %%
from  PlaneModel import job,aircraft,staff,problem,workOrder

# %% [markdown]
# ### Import Data Generator and its aircraft instaces method

# %%
from generate_aircrafts_seed import generate_aircraft_instances

# %% [markdown]
# ### Import EA Computing Functions and Depencies

# %%
from EA_Model import randSol, evaluate, mutate, copyG, contains, xo, tour, rip

# %% [markdown]
# ### Generate CSV file with specified input parameters
#
# Commented out as we've already generated CSV files

# %%
# generate_aircraft_instances(
#     work_packages_file="work_packages.csv",  # Relative Path to WP input CSV
#     output_dir="generated_aircrafts",        # Output directory name
#     num_instances=80,                        # Number of CSV files to generate
#     seed=20                                  # Fix the seed to 20 to ensure reproducibility
# )

# %% [markdown]
# ### Conditional Checking of Data Directory

# %%
def is_directory_empty(path_directory):
    """
    Check if a directory is empty.
    """
    path = Path(path_directory)
    # Check if the path exists and is a directory
    if not path.exists() or not path.is_dir():
        raise ValueError("Invalid directory path")
    # check if the directory is empty
    return not any(path.iterdir())

# %%
path_directory = "generated_aircrafts"
try:
    if is_directory_empty(path_directory):
        print("Directory is empty")
    else:
        print("sample aircrfat instances are generated")
except ValueError as e:
    print(e)
    sys.exit(1)
# Out:
# sample aircrfat instances are generated

# %% [markdown]
# ### Reading Work Packages and Technicians files to DF

# %%
work_packages = pd.read_csv('work_packages.csv', index_col=0)
people = pd.read_csv('technicians.csv')
work_orders = pd.read_csv('work_packages_work_orders.csv', index_col = 0)

# %% [markdown]
# ## Load Problem instance from the directory of database

# %%
# Path to the directory containing the CSV files
db_path = './generated_aircrafts'

# Get a list of all CSV files in the directory
csv_files = glob.glob(os.path.join(db_path, '*.csv'))

# %%
#create a dict to store the aircraft samples
aircraft_samples = {}

# Loop through each CSV file and read it into a DataFrame
for csv_file in csv_files:
    # Extract the filename without the directory and extension
    filename = os.path.splitext(os.path.basename(csv_file))[0]
    
    # Read the CSV file into a DataFrame
    df = pd.read_csv(csv_file)
    
    # Store the DataFrame in the dictionary with the filename as the key
    aircraft_samples[filename] = df

# %% [markdown]
# ### Input Logs Code and CSV File

# %%
# Create logs directory if it doesn't exist
os.makedirs('logs', exist_ok=True)

wp_origin = pd.read_csv('work_packages.csv')

# map the WP numbers to minutes into the dictionary
wp_time_dict = wp_origin.set_index("WP number")["Minutes"].astype(int).to_dict()
wp_personnel_dict = wp_origin.set_index("WP number")["Number of Personnel"].astype(int).to_dict()


# List to store results for each file
results = []
    
# Loop through each DataFrame in the dictionary
for filename, df in aircraft_samples.items():
    
     # calculate total number of rows in the dataframe
    aircraft_num = len(df)
    
    # Total Turnaround Time (Column F)
    # Convert HH:MM to total minutes for summing
    tat = df['Turn Around Time'].str.split(':', expand=True).astype(int)
    total_minutes = (tat[0] * 60 + tat[1]).sum()
    total_tat = f"{total_minutes}"
    # total_hours, total_mins = divmod(total_minutes, 60)
    # total_tat = f"{total_hours}:{total_mins:02d}"
    
    # Average Turnaround Time
    avg_minutes = total_minutes / aircraft_num
    avg_hours, avg_mins = divmod(int(avg_minutes), 60)
    avg_tat = f"{avg_hours}:{avg_mins:02d}"
    
    # Total WPs (Column G)
    wp_counts = df['Work that needs to be carried out'].apply(lambda x: len(str(x).split(', ')))
    total_wps = wp_counts.sum()
    avg_wps = round(wp_counts.mean(), 2)  # New metric: average WPs
    
    total_work_minutes = 0
    total_personnel = 0
    for wp_list in df['Work that needs to be carried out']:
        wps = str(wp_list).split(', ')
        for wp in wps:
            wp = wp.strip()
            total_work_minutes += wp_time_dict.get(wp, 0)  # Default to 0 if WP not found
            total_personnel += wp_personnel_dict.get(wp, 0)
            
            
    # Average personnel per WP
    if total_wps > 0:
        avg_personnel_per_wp = round(total_personnel / total_wps, 2) 
    else:
        avg_personnel_per_wp = 0

    
    results.append({
        'Filename': filename,
        'Total Aircraft Serial Numbers': aircraft_num,
        'Total Turnaround Time Minutes': total_tat,
        'Average Turnaround Time': avg_tat,
        'Total Number WPs': total_wps,
        'Average Number WPs': avg_wps,
        'Total Work Minutes': total_work_minutes,
        'Average Personnel per WP': avg_personnel_per_wp,
    })
    
# Create a DataFrame from the results list
results_df = pd.DataFrame(results)


output_path = os.path.join('logs', '1stlog.csv')
results_df.to_csv(output_path, index=False)
print(f"Aircraft sample work summary saved to {output_path}")
# Out:
# Aircraft sample work summary saved to logs/1stlog.csv

# %% [markdown]
# ### Call the EA Model and Populate it with DataFrames of Aircraft Samples

# %% [markdown]
# #### Fine-tuning the EA outputs

# %%
#create a logs directory if it doesn't exist
os.makedirs('logs', exist_ok=True)

#create a CSV output file with the summary of the aircraft samples and svae it in the logs directory
with open(os.path.join('logs', '2ndlog.csv'), 'w', newline='') as csvfile:
    fieldnames = [ 'Problem ID', 
        'Run Number', 
        'Initial Best', 
        'Evals', 
        'Improved Fitness', 
        'Missing Staff']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    


    for k , planes in aircraft_samples.items():
        instance = problem(people,planes,work_packages,work_orders)

        print(f"Running for {k} instance")

        fitness_All = []
        for run in range(10):
            pop_size = 1500 
            budget = 200000
     
            best = None

            pop = []
            for c in range(pop_size):
                
                i = randSol(instance)
                f= evaluate(i, instance)[0]
                p = (f, i)
                pop.append(p)
                if len(pop) == 1:
                    best = p
                if f < best[0]:
                    best = p

            print(f"Run {run + 1} - Init")
            print(f"Initial best: {best[0]}")

            evals = 0
            
            while evals < budget:
                evals += 1
                if random.choice([True, False]):
                    parent = tour(pop)
                    ng = copyG(parent[1])
                else:
                    ng = xo(tour(pop)[1], tour(pop)[1])
                
                mutate(ng, instance)
                nf = evaluate(ng, instance)[0]
                child = (nf, ng)

                toGo = rip(pop)
                if toGo[0] > child[0]:
                    pop.remove(toGo)
                    pop.append(child)
                    if child[0] < best[0]:
                        best = (child[0], copyG(child[1]))
                        instance.reset()
                        r = evaluate(best[1], instance)
                        print(f"Evals: {evals}")
                        print(f"Improved ({r[0]}) Missing staff = {r[1]} Late = {r[2]} Late mins = {r[3]}")
                        
                        #update the CSV file variables
                        run_best_fitness = r[0]
                        run_best_evals = evals
                        run_missing_staff = r[1]
                        
                        
            #write the results for each run to the CSV file
            writer.writerow({
                'Problem ID': k, 
                'Run Number': run + 1, 
                'Initial Best': best[0], 
                'Evals': run_best_evals, 
                'Improved Fitness': run_best_fitness, 
                'Missing Staff': run_missing_staff
            })
                        

            fitness_All.append(best[0])
            print(f"Run {run + 1} - Done: {best[0]}\n")
            
            #create a directory for the solutions if it doesn't exist
            os.makedirs("solutions", exist_ok=True)
            
            #Crrate a filename with path
            filename = os.path.join("solutions", f"{k}_run_{run + 1}_solution.txt")
            
            #write the solution to a txt file
            instance.reset()
            r = evaluate(best[1], instance)
            with open(filename, "w") as f:
                f.write(f"Fitness = {r[0]}\n")
                f.write(f"Missing staff: {r[1]}\n")
                f.write(f"Late Departures: {r[2]}\n")
                f.write(f"Late mins: {r[3]}\n")
                f.write(f"\n Plan : \n\n{instance}")
            
    # compute the average of fitness values in the population for 10 iterations
    np_avg_fitness = np.mean(fitness_All)
    avg_fitness = sum(fitness_All) / len(fitness_All)
    print(f"Average fitness over 10 runs: Math Method {avg_fitness} and Numpy Method {np_avg_fitness}")

    # compute standard deviation of fitness values in the population for 10 iterations
    std_dev = np.std(fitness_All)
    print(f"Standard Deviation: {std_dev}")
# Out:
# Running for aircrafts_sample_57 instance
# Run 1 - Init
# Initial best: 142
# Evals: 44
# Improved (141) Missing staff = 61 Late = 8 Late mins = 80
# Evals: 66
# Improved (126) Missing staff = 56 Late = 7 Late mins = 70
# Evals: 70
# Improved (125) Missing staff = 55 Late = 7 Late mins = 70
# Evals: 91
# Improved (124) Missing staff = 54 Late = 7 Late mins = 70
# Evals: 96
# Improved (117) Missing staff = 47 Late = 7 Late mins = 70
# Evals: 99
# Improved (115) Missing staff = 45 Late = 7 Late mins = 70
# Run 1 - Done: 115
#
# Run 2 - Init
# Initial best: 129
# Run 2 - Done: 129
#
# Run 3 - Init
# Initial best: 139
# Evals: 62
# Improved (138) Missing staff = 48 Late = 9 Late mins = 90
# Evals: 71
# Improved (136) Missing staff = 46 Late = 9 Late mins = 90
# Evals: 75
# Improved (135) Missing staff = 45 Late = 9 Late mins = 90
# Evals: 88
# Improved (130) Missing staff = 50 Late = 8 Late mins = 80
# Run 3 - Done: 130
#
# Run 4 - Init
# Initial best: 153
# Evals: 1
# Improved (145) Missing staff = 45 Late = 10 Late mins = 100
# Evals: 13
# Improved (144) Missing staff = 64 Late = 8 Late mins = 80
# Evals: 30
# Improved (141) Missing staff = 51 Late = 9 Late mins = 90
# Evals: 33
# Improved (139) Missing staff = 59 Late = 8 Late mins = 80
# Evals: 52
# Improved (138) Missing staff = 58 Late = 8 Late mins = 80
# Evals: 54
# Improved (137) Missing staff = 57 Late = 8 Late mins = 80
# Evals: 56
# Improved (136) Missing staff = 56 Late = 8 Late mins = 80
# Evals: 68
# Improved (134) Missing staff = 54 Late = 8 Late mins = 80
# Evals: 70
# Improved (132) Missing staff = 52 Late = 8 Late mins = 80
# Run 4 - Done: 132
#
# Run 5 - Init
# Initial best: 148
# Evals: 8
# Improved (142) Missing staff = 62 Late = 8 Late mins = 80
# Evals: 35
# Improved (140) Missing staff = 40 Late = 10 Late mins = 100
# Evals: 79
# Improved (137) Missing staff = 57 Late = 8 Late mins = 80
# Evals: 83
# Improved (134) Missing staff = 54 Late = 8 Late mins = 80
# Evals: 86
# Improved (131) Missing staff = 51 Late = 8 Late mins = 80
# Evals: 88
# Improved (128) Missing staff = 48 Late = 8 Late mins = 80
# Run 5 - Done: 128
#
# Running for aircrafts_sample_43 instance
# Run 1 - Init
# Initial best: 143
# Evals: 7
# Improved (139) Missing staff = 49 Late = 9 Late mins = 90
# Evals: 9
# Improved (138) Missing staff = 58 Late = 8 Late mins = 80
# Evals: 20
# Improved (132) Missing staff = 42 Late = 9 Late mins = 90
# Evals: 39
# Improved (129) Missing staff = 39 Late = 9 Late mins = 90
# Evals: 40
# Improved (127) Missing staff = 37 Late = 9 Late mins = 90
# Evals: 49
# Improved (126) Missing staff = 36 Late = 9 Late mins = 90
# Evals: 92
# Improved (125) Missing staff = 35 Late = 9 Late mins = 90
# Run 1 - Done: 125
#
# Run 2 - Init
# Initial best: 135
# Evals: 13
# Improved (134) Missing staff = 44 Late = 9 Late mins = 90
# Evals: 22
# Improved (132) Missing staff = 42 Late = 9 Late mins = 90
# Evals: 28
# Improved (118) Missing staff = 48 Late = 7 Late mins = 70
# Evals: 50
# Improved (112) Missing staff = 52 Late = 6 Late mins = 60
# Evals: 81
# Improved (105) Missing staff = 55 Late = 5 Late mins = 50
# Run 2 - Done: 105
#
# Run 3 - Init
# Initial best: 152
# Evals: 1
# Improved (150) Missing staff = 50 Late = 10 Late mins = 100
# Evals: 8
# Improved (139) Missing staff = 39 Late = 10 Late mins = 100
# Evals: 26
# Improved (137) Missing staff = 37 Late = 10 Late mins = 100
# Evals: 43
# Improved (136) Missing staff = 36 Late = 10 Late mins = 100
# Evals: 53
# Improved (126) Missing staff = 36 Late = 9 Late mins = 90
# Evals: 71
# Improved (122) Missing staff = 32 Late = 9 Late mins = 90
# Evals: 91
# Improved (114) Missing staff = 34 Late = 8 Late mins = 80
# Evals: 93
# Improved (113) Missing staff = 33 Late = 8 Late mins = 80
# Evals: 95
# Improved (103) Missing staff = 33 Late = 7 Late mins = 70
# Run 3 - Done: 103
#
# Run 4 - Init
# Initial best: 138
# Evals: 1
# Improved (126) Missing staff = 46 Late = 8 Late mins = 80
# Evals: 10
# Improved (112) Missing staff = 42 Late = 7 Late mins = 70
# Evals: 23
# Improved (109) Missing staff = 39 Late = 7 Late mins = 70
# Run 4 - Done: 109
#
# Run 5 - Init
# Initial best: 120
# Evals: 8
# Improved (114) Missing staff = 44 Late = 7 Late mins = 70
# Evals: 14
# Improved (113) Missing staff = 43 Late = 7 Late mins = 70
# Evals: 17
# Improved (111) Missing staff = 41 Late = 7 Late mins = 70
# Evals: 48
# Improved (105) Missing staff = 35 Late = 7 Late mins = 70
# Evals: 52
# Improved (96) Missing staff = 36 Late = 6 Late mins = 60
# Evals: 57
# Improved (83) Missing staff = 33 Late = 5 Late mins = 50
# Evals: 66
# Improved (73) Missing staff = 33 Late = 4 Late mins = 40
# Run 5 - Done: 73
#
# Running for aircrafts_sample_80 instance
# Run 1 - Init
# Initial best: 110
# Evals: 3
# Improved (109) Missing staff = 39 Late = 7 Late mins = 70
# Evals: 11
# Improved (108) Missing staff = 38 Late = 7 Late mins = 70
# Evals: 19
# Improved (94) Missing staff = 24 Late = 7 Late mins = 70
# Evals: 49
# Improved (87) Missing staff = 27 Late = 6 Late mins = 60
# Evals: 72
# Improved (85) Missing staff = 25 Late = 6 Late mins = 60
# Evals: 91
# Improved (84) Missing staff = 24 Late = 6 Late mins = 60
# Run 1 - Done: 84
#
# Run 2 - Init
# Initial best: 104
# Evals: 17
# Improved (103) Missing staff = 43 Late = 6 Late mins = 60
# Evals: 24
# Improved (99) Missing staff = 39 Late = 6 Late mins = 60
# Evals: 32
# Improved (95) Missing staff = 45 Late = 5 Late mins = 50
# Evals: 62
# Improved (93) Missing staff = 43 Late = 5 Late mins = 50
# Run 2 - Done: 93
#
# Run 3 - Init
# Initial best: 109
# Evals: 11
# Improved (80) Missing staff = 30 Late = 5 Late mins = 50
# Evals: 19
# Improved (77) Missing staff = 37 Late = 4 Late mins = 40
# Evals: 51
# Improved (70) Missing staff = 30 Late = 4 Late mins = 40
# Evals: 55
# Improved (69) Missing staff = 29 Late = 4 Late mins = 40
# Evals: 66
# Improved (60) Missing staff = 30 Late = 3 Late mins = 30
# Evals: 75
# Improved (58) Missing staff = 28 Late = 3 Late mins = 30
# Run 3 - Done: 58
#
# Run 4 - Init
# Initial best: 108
# Evals: 15
# Improved (99) Missing staff = 39 Late = 6 Late mins = 60
# Evals: 28
# Improved (87) Missing staff = 37 Late = 5 Late mins = 50
# Evals: 63
# Improved (85) Missing staff = 35 Late = 5 Late mins = 50
# Evals: 76
# Improved (79) Missing staff = 39 Late = 4 Late mins = 40
# Evals: 82
# Improved (78) Missing staff = 38 Late = 4 Late mins = 40
# Evals: 84
# Improved (74) Missing staff = 34 Late = 4 Late mins = 40
# Run 4 - Done: 74
#
# Run 5 - Init
# Initial best: 109
# Evals: 34
# Improved (108) Missing staff = 48 Late = 6 Late mins = 60
# Evals: 53
# Improved (105) Missing staff = 35 Late = 7 Late mins = 70
# Evals: 82
# Improved (99) Missing staff = 49 Late = 5 Late mins = 50
# Run 5 - Done: 99
#
# Running for aircrafts_instance_2 instance
# Run 1 - Init
# Initial best: 140
# Evals: 16
# Improved (130) Missing staff = 50 Late = 8 Late mins = 80
# Evals: 57
# Improved (127) Missing staff = 57 Late = 7 Late mins = 70
# Evals: 67
# Improved (123) Missing staff = 53 Late = 7 Late mins = 70
# Evals: 81
# Improved (118) Missing staff = 58 Late = 6 Late mins = 60
# Evals: 85
# Improved (110) Missing staff = 60 Late = 5 Late mins = 50
# Run 1 - Done: 110
#
# Run 2 - Init
# Initial best: 148
# Evals: 6
# Improved (147) Missing staff = 57 Late = 9 Late mins = 90
# Evals: 14
# Improved (130) Missing staff = 40 Late = 9 Late mins = 90
# Evals: 31
# Improved (125) Missing staff = 45 Late = 8 Late mins = 80
# Evals: 39
# Improved (118) Missing staff = 38 Late = 8 Late mins = 80
# Evals: 40
# Improved (113) Missing staff = 33 Late = 8 Late mins = 80
# Evals: 71
# Improved (112) Missing staff = 32 Late = 8 Late mins = 80
# Evals: 77
# Improved (111) Missing staff = 31 Late = 8 Late mins = 80
# Evals: 78
# Improved (104) Missing staff = 34 Late = 7 Late mins = 70
# Evals: 90
# Improved (102) Missing staff = 32 Late = 7 Late mins = 70
# Evals: 91
# Improved (101) Missing staff = 31 Late = 7 Late mins = 70
# Run 2 - Done: 101
#
# Run 3 - Init
# Initial best: 128
# Evals: 6
# Improved (113) Missing staff = 33 Late = 8 Late mins = 80
# Evals: 8
# Improved (99) Missing staff = 29 Late = 7 Late mins = 70
# Evals: 23
# Improved (98) Missing staff = 28 Late = 7 Late mins = 70
# Evals: 34
# Improved (86) Missing staff = 26 Late = 6 Late mins = 60
# Evals: 71
# Improved (85) Missing staff = 35 Late = 5 Late mins = 50
# Evals: 76
# Improved (83) Missing staff = 23 Late = 6 Late mins = 60
# Evals: 81
# Improved (82) Missing staff = 32 Late = 5 Late mins = 50
# Evals: 82
# Improved (80) Missing staff = 30 Late = 5 Late mins = 50
# Evals: 96
# Improved (79) Missing staff = 19 Late = 6 Late mins = 60
# Evals: 97
# Improved (78) Missing staff = 28 Late = 5 Late mins = 50
# Evals: 100
# Improved (76) Missing staff = 26 Late = 5 Late mins = 50
# Run 3 - Done: 76
#
# Run 4 - Init
# Initial best: 126
# Evals: 14
# Improved (113) Missing staff = 23 Late = 9 Late mins = 90
# Evals: 20
# Improved (111) Missing staff = 21 Late = 9 Late mins = 90
# Evals: 27
# Improved (110) Missing staff = 30 Late = 8 Late mins = 80
# Evals: 45
# Improved (104) Missing staff = 34 Late = 7 Late mins = 70
# Evals: 50
# Improved (101) Missing staff = 21 Late = 8 Late mins = 80
# Evals: 60
# Improved (100) Missing staff = 30 Late = 7 Late mins = 70
# Evals: 62
# Improved (91) Missing staff = 21 Late = 7 Late mins = 70
# Evals: 64
# Improved (86) Missing staff = 26 Late = 6 Late mins = 60
# Run 4 - Done: 86
#
# Run 5 - Init
# Initial best: 111
# Evals: 32
# Improved (101) Missing staff = 31 Late = 7 Late mins = 70
# Evals: 38
# Improved (100) Missing staff = 30 Late = 7 Late mins = 70
# Evals: 71
# Improved (98) Missing staff = 28 Late = 7 Late mins = 70
# Evals: 89
# Improved (96) Missing staff = 26 Late = 7 Late mins = 70
# Run 5 - Done: 96
#
# Running for aircrafts_sample_3 instance
# Run 1 - Init
# Initial best: 131
# Evals: 4
# Improved (127) Missing staff = 47 Late = 8 Late mins = 80
# Evals: 6
# Improved (109) Missing staff = 29 Late = 8 Late mins = 80
# Run 1 - Done: 109
#
# Run 2 - Init
# Initial best: 147
# Evals: 1
# Improved (142) Missing staff = 62 Late = 8 Late mins = 80
# Evals: 2
# Improved (129) Missing staff = 49 Late = 8 Late mins = 80
# Evals: 76
# Improved (124) Missing staff = 44 Late = 8 Late mins = 80
# Run 2 - Done: 124
#
# Run 3 - Init
# Initial best: 136
# Evals: 1
# Improved (125) Missing staff = 45 Late = 8 Late mins = 80
# Run 3 - Done: 125
#
# Run 4 - Init
# Initial best: 144
# Evals: 11
# Improved (134) Missing staff = 44 Late = 9 Late mins = 90
# Evals: 18
# Improved (133) Missing staff = 43 Late = 9 Late mins = 90
# Evals: 24
# Improved (127) Missing staff = 37 Late = 9 Late mins = 90
# Evals: 45
# Improved (126) Missing staff = 46 Late = 8 Late mins = 80
# Evals: 56
# Improved (125) Missing staff = 45 Late = 8 Late mins = 80
# Evals: 58
# Improved (122) Missing staff = 42 Late = 8 Late mins = 80
# Evals: 70
# Improved (116) Missing staff = 36 Late = 8 Late mins = 80
# Evals: 73
# Improved (115) Missing staff = 35 Late = 8 Late mins = 80
# Evals: 81
# Improved (114) Missing staff = 34 Late = 8 Late mins = 80
# Evals: 98
# Improved (113) Missing staff = 33 Late = 8 Late mins = 80
# Run 4 - Done: 113
#
# Run 5 - Init
# Initial best: 127
# Evals: 4
# Improved (126) Missing staff = 36 Late = 9 Late mins = 90
# Evals: 10
# Improved (123) Missing staff = 33 Late = 9 Late mins = 90
# Evals: 14
# Improved (122) Missing staff = 42 Late = 8 Late mins = 80
# Evals: 21
# Improved (121) Missing staff = 41 Late = 8 Late mins = 80
# Evals: 24
# Improved (115) Missing staff = 35 Late = 8 Late mins = 80
# Evals: 28
# Improved (113) Missing staff = 53 Late = 6 Late mins = 60
# Evals: 51
# Improved (110) Missing staff = 40 Late = 7 Late mins = 70
# Evals: 96
# Improved (101) Missing staff = 41 Late = 6 Late mins = 60
# Run 5 - Done: 101
#
# Running for aircrafts_instance_19 instance
# Run 1 - Init
# Initial best: 138
# Evals: 22
# Improved (127) Missing staff = 37 Late = 9 Late mins = 90
# Evals: 25
# Improved (124) Missing staff = 34 Late = 9 Late mins = 90
# Evals: 27
# Improved (101) Missing staff = 41 Late = 6 Late mins = 60
# Evals: 41
# Improved (96) Missing staff = 36 Late = 6 Late mins = 60
# Evals: 58
# Improved (95) Missing staff = 35 Late = 6 Late mins = 60
# Evals: 60
# Improved (94) Missing staff = 34 Late = 6 Late mins = 60
# Evals: 64
# Improved (85) Missing staff = 35 Late = 5 Late mins = 50
# Evals: 78
# Improved (82) Missing staff = 32 Late = 5 Late mins = 50
# Run 1 - Done: 82
#
# Run 2 - Init
# Initial best: 145
# Evals: 29
# Improved (135) Missing staff = 35 Late = 10 Late mins = 100
# Evals: 31
# Improved (134) Missing staff = 34 Late = 10 Late mins = 100
# Evals: 41
# Improved (111) Missing staff = 31 Late = 8 Late mins = 80
# Run 2 - Done: 111
#
# Run 3 - Init
# Initial best: 143
# Evals: 9
# Improved (142) Missing staff = 32 Late = 11 Late mins = 110
# Evals: 15
# Improved (132) Missing staff = 32 Late = 10 Late mins = 100
# Evals: 35
# Improved (123) Missing staff = 33 Late = 9 Late mins = 90
# Evals: 71
# Improved (116) Missing staff = 26 Late = 9 Late mins = 90
# Run 3 - Done: 116
#
# Run 4 - Init
# Initial best: 143
# Evals: 3
# Improved (115) Missing staff = 35 Late = 8 Late mins = 80
# Evals: 17
# Improved (107) Missing staff = 37 Late = 7 Late mins = 70
# Evals: 29
# Improved (106) Missing staff = 36 Late = 7 Late mins = 70
# Evals: 37
# Improved (105) Missing staff = 35 Late = 7 Late mins = 70
# Evals: 50
# Improved (98) Missing staff = 38 Late = 6 Late mins = 60
# Run 4 - Done: 98
#
# Run 5 - Init
# Initial best: 147
# Evals: 8
# Improved (138) Missing staff = 28 Late = 11 Late mins = 110
# Evals: 17
# Improved (132) Missing staff = 32 Late = 10 Late mins = 100
# Evals: 32
# Improved (124) Missing staff = 24 Late = 10 Late mins = 100
# Evals: 43
# Improved (121) Missing staff = 21 Late = 10 Late mins = 100
# Evals: 68
# Improved (118) Missing staff = 28 Late = 9 Late mins = 90
# Evals: 73
# Improved (117) Missing staff = 27 Late = 9 Late mins = 90
# Evals: 87
# Improved (115) Missing staff = 35 Late = 8 Late mins = 80
# Run 5 - Done: 115
#
# Running for aircrafts_instance_18 instance
# Run 1 - Init
# Initial best: 141
# Evals: 4
# Improved (140) Missing staff = 50 Late = 9 Late mins = 90
# Evals: 30
# Improved (139) Missing staff = 49 Late = 9 Late mins = 90
# Evals: 40
# Improved (130) Missing staff = 50 Late = 8 Late mins = 80
# Evals: 48
# Improved (120) Missing staff = 50 Late = 7 Late mins = 70
# Evals: 76
# Improved (119) Missing staff = 49 Late = 7 Late mins = 70
# Evals: 90
# Improved (118) Missing staff = 48 Late = 7 Late mins = 70
# Evals: 94
# Improved (110) Missing staff = 50 Late = 6 Late mins = 60
# Evals: 99
# Improved (108) Missing staff = 48 Late = 6 Late mins = 60
# Run 1 - Done: 108
#
# Run 2 - Init
# Initial best: 160
# Evals: 9
# Improved (159) Missing staff = 29 Late = 13 Late mins = 130
# Evals: 14
# Improved (150) Missing staff = 40 Late = 11 Late mins = 110
# Evals: 39
# Improved (141) Missing staff = 41 Late = 10 Late mins = 100
# Evals: 65
# Improved (140) Missing staff = 40 Late = 10 Late mins = 100
# Evals: 81
# Improved (137) Missing staff = 37 Late = 10 Late mins = 100
# Run 2 - Done: 137
#
# Run 3 - Init
# Initial best: 130
# Evals: 4
# Improved (125) Missing staff = 35 Late = 9 Late mins = 90
# Evals: 42
# Improved (124) Missing staff = 34 Late = 9 Late mins = 90
# Evals: 59
# Improved (116) Missing staff = 36 Late = 8 Late mins = 80
# Run 3 - Done: 116
#
# Run 4 - Init
# Initial best: 155
# Evals: 12
# Improved (135) Missing staff = 55 Late = 8 Late mins = 80
# Evals: 25
# Improved (133) Missing staff = 53 Late = 8 Late mins = 80
# Evals: 32
# Improved (130) Missing staff = 50 Late = 8 Late mins = 80
# Evals: 46
# Improved (127) Missing staff = 47 Late = 8 Late mins = 80
# Evals: 48
# Improved (122) Missing staff = 42 Late = 8 Late mins = 80
# Evals: 75
# Improved (120) Missing staff = 50 Late = 7 Late mins = 70
# Evals: 79
# Improved (118) Missing staff = 48 Late = 7 Late mins = 70
# Evals: 81
# Improved (116) Missing staff = 46 Late = 7 Late mins = 70
# Run 4 - Done: 116
#
# Run 5 - Init
# Initial best: 145
# Evals: 19
# Improved (144) Missing staff = 44 Late = 10 Late mins = 100
# Evals: 27
# Improved (143) Missing staff = 43 Late = 10 Late mins = 100
# Evals: 39
# Improved (133) Missing staff = 43 Late = 9 Late mins = 90
# Evals: 65
# Improved (132) Missing staff = 42 Late = 9 Late mins = 90
# Evals: 78
# Improved (130) Missing staff = 50 Late = 8 Late mins = 80
# Run 5 - Done: 130
#
# Running for aircrafts_sample_2 instance
# Run 1 - Init
# Initial best: 112
# Evals: 22
# Improved (108) Missing staff = 38 Late = 7 Late mins = 70
# Evals: 47
# Improved (107) Missing staff = 37 Late = 7 Late mins = 70
# Evals: 57
# Improved (106) Missing staff = 36 Late = 7 Late mins = 70
# Evals: 62
# Improved (104) Missing staff = 34 Late = 7 Late mins = 70
# Evals: 77
# Improved (103) Missing staff = 33 Late = 7 Late mins = 70
# Evals: 91
# Improved (98) Missing staff = 38 Late = 6 Late mins = 60
# Run 1 - Done: 98
#
# Run 2 - Init
# Initial best: 107
# Evals: 16
# Improved (89) Missing staff = 49 Late = 4 Late mins = 40
# Evals: 17
# Improved (88) Missing staff = 48 Late = 4 Late mins = 40
# Evals: 21
# Improved (86) Missing staff = 46 Late = 4 Late mins = 40
# Evals: 41
# Improved (84) Missing staff = 44 Late = 4 Late mins = 40
# Evals: 59
# Improved (82) Missing staff = 42 Late = 4 Late mins = 40
# Evals: 67
# Improved (80) Missing staff = 40 Late = 4 Late mins = 40
# Run 2 - Done: 80
#
# Run 3 - Init
# Initial best: 94
# Evals: 17
# Improved (93) Missing staff = 23 Late = 7 Late mins = 70
# Evals: 36
# Improved (92) Missing staff = 22 Late = 7 Late mins = 70
# Evals: 44
# Improved (86) Missing staff = 26 Late = 6 Late mins = 60
# Evals: 49
# Improved (84) Missing staff = 24 Late = 6 Late mins = 60
# Evals: 68
# Improved (77) Missing staff = 27 Late = 5 Late mins = 50
# Run 3 - Done: 77
#
# Run 4 - Init
# Initial best: 116
# Evals: 3
# Improved (108) Missing staff = 38 Late = 7 Late mins = 70
# Evals: 11
# Improved (107) Missing staff = 37 Late = 7 Late mins = 70
# Evals: 78
# Improved (106) Missing staff = 36 Late = 7 Late mins = 70
# Evals: 96
# Improved (105) Missing staff = 35 Late = 7 Late mins = 70
# Run 4 - Done: 105
#
# Run 5 - Init
# Initial best: 99
# Evals: 12
# Improved (98) Missing staff = 38 Late = 6 Late mins = 60
# Evals: 14
# Improved (93) Missing staff = 43 Late = 5 Late mins = 50
# Evals: 26
# Improved (92) Missing staff = 42 Late = 5 Late mins = 50
# Evals: 34
# Improved (89) Missing staff = 49 Late = 4 Late mins = 40
# Evals: 35
# Improved (82) Missing staff = 42 Late = 4 Late mins = 40
# Evals: 37
# Improved (81) Missing staff = 41 Late = 4 Late mins = 40
# Evals: 97
# Improved (77) Missing staff = 37 Late = 4 Late mins = 40
# Run 5 - Done: 77
#
# Running for aircrafts_instance_3 instance
# Run 1 - Init
# Initial best: 153
# Evals: 22
# Improved (141) Missing staff = 31 Late = 11 Late mins = 110
# Evals: 54
# Improved (133) Missing staff = 33 Late = 10 Late mins = 100
# Evals: 89
# Improved (132) Missing staff = 32 Late = 10 Late mins = 100
# Evals: 100
# Improved (124) Missing staff = 34 Late = 9 Late mins = 90
# Run 1 - Done: 124
#
# Run 2 - Init
# Initial best: 156
# Evals: 40
# Improved (148) Missing staff = 38 Late = 11 Late mins = 110
# Evals: 63
# Improved (147) Missing staff = 37 Late = 11 Late mins = 110
# Evals: 83
# Improved (145) Missing staff = 35 Late = 11 Late mins = 110
# Evals: 87
# Improved (137) Missing staff = 37 Late = 10 Late mins = 100
# Run 2 - Done: 137
#
# Run 3 - Init
# Initial best: 155
# Evals: 16
# Improved (150) Missing staff = 40 Late = 11 Late mins = 110
# Evals: 31
# Improved (142) Missing staff = 52 Late = 9 Late mins = 90
# Evals: 63
# Improved (141) Missing staff = 51 Late = 9 Late mins = 90
# Evals: 66
# Improved (140) Missing staff = 50 Late = 9 Late mins = 90
# Evals: 67
# Improved (131) Missing staff = 41 Late = 9 Late mins = 90
# Evals: 68
# Improved (130) Missing staff = 40 Late = 9 Late mins = 90
# Run 3 - Done: 130
#
# Run 4 - Init
# Initial best: 159
# Evals: 5
# Improved (156) Missing staff = 56 Late = 10 Late mins = 100
# Evals: 6
# Improved (145) Missing staff = 55 Late = 9 Late mins = 90
# Evals: 13
# Improved (139) Missing staff = 49 Late = 9 Late mins = 90
# Evals: 26
# Improved (138) Missing staff = 48 Late = 9 Late mins = 90
# Evals: 32
# Improved (135) Missing staff = 45 Late = 9 Late mins = 90
# Evals: 34
# Improved (120) Missing staff = 50 Late = 7 Late mins = 70
# Evals: 51
# Improved (115) Missing staff = 45 Late = 7 Late mins = 70
# Evals: 68
# Improved (114) Missing staff = 44 Late = 7 Late mins = 70
# Evals: 76
# Improved (113) Missing staff = 43 Late = 7 Late mins = 70
# Evals: 90
# Improved (112) Missing staff = 42 Late = 7 Late mins = 70
# Run 4 - Done: 112
#
# Run 5 - Init
# Initial best: 145
# Evals: 25
# Improved (137) Missing staff = 47 Late = 9 Late mins = 90
# Evals: 28
# Improved (136) Missing staff = 46 Late = 9 Late mins = 90
# Evals: 33
# Improved (118) Missing staff = 38 Late = 8 Late mins = 80
# Evals: 91
# Improved (102) Missing staff = 32 Late = 7 Late mins = 70
# Run 5 - Done: 102
#
# Running for aircrafts_sample_42 instance
# Run 1 - Init
# Initial best: 167
# Evals: 3
# Improved (157) Missing staff = 37 Late = 12 Late mins = 120
# Evals: 16
# Improved (147) Missing staff = 47 Late = 10 Late mins = 100
# Evals: 24
# Improved (146) Missing staff = 46 Late = 10 Late mins = 100
# Evals: 34
# Improved (145) Missing staff = 35 Late = 11 Late mins = 110
# Evals: 45
# Improved (144) Missing staff = 44 Late = 10 Late mins = 100
# Evals: 91
# Improved (142) Missing staff = 42 Late = 10 Late mins = 100
# Evals: 94
# Improved (132) Missing staff = 42 Late = 9 Late mins = 90
# Run 1 - Done: 132
#
# Run 2 - Init
# Initial best: 156
# Evals: 4
# Improved (152) Missing staff = 82 Late = 7 Late mins = 70
# Evals: 13
# Improved (151) Missing staff = 81 Late = 7 Late mins = 70
# Evals: 30
# Improved (149) Missing staff = 79 Late = 7 Late mins = 70
# Evals: 38
# Improved (145) Missing staff = 85 Late = 6 Late mins = 60
# Evals: 44
# Improved (135) Missing staff = 85 Late = 5 Late mins = 50
# Run 2 - Done: 135
#
# Run 3 - Init
# Initial best: 151
# Evals: 3
# Improved (144) Missing staff = 54 Late = 9 Late mins = 90
# Evals: 44
# Improved (143) Missing staff = 53 Late = 9 Late mins = 90
# Evals: 51
# Improved (142) Missing staff = 52 Late = 9 Late mins = 90
# Evals: 52
# Improved (137) Missing staff = 57 Late = 8 Late mins = 80
# Evals: 55
# Improved (131) Missing staff = 51 Late = 8 Late mins = 80
# Evals: 80
# Improved (129) Missing staff = 49 Late = 8 Late mins = 80
# Evals: 84
# Improved (118) Missing staff = 48 Late = 7 Late mins = 70
# Run 3 - Done: 118
#
# Run 4 - Init
# Initial best: 167
# Evals: 10
# Improved (166) Missing staff = 66 Late = 10 Late mins = 100
# Evals: 15
# Improved (164) Missing staff = 64 Late = 10 Late mins = 100
# Evals: 20
# Improved (154) Missing staff = 64 Late = 9 Late mins = 90
# Evals: 32
# Improved (153) Missing staff = 63 Late = 9 Late mins = 90
# Evals: 39
# Improved (145) Missing staff = 65 Late = 8 Late mins = 80
# Evals: 61
# Improved (135) Missing staff = 65 Late = 7 Late mins = 70
# Evals: 69
# Improved (134) Missing staff = 64 Late = 7 Late mins = 70
# Evals: 88
# Improved (126) Missing staff = 56 Late = 7 Late mins = 70
# Evals: 94
# Improved (125) Missing staff = 55 Late = 7 Late mins = 70
# Run 4 - Done: 125
#
# Run 5 - Init
# Initial best: 173
# Evals: 13
# Improved (169) Missing staff = 59 Late = 11 Late mins = 110
# Evals: 15
# Improved (165) Missing staff = 55 Late = 11 Late mins = 110
# Evals: 22
# Improved (163) Missing staff = 53 Late = 11 Late mins = 110
# Evals: 26
# Improved (157) Missing staff = 37 Late = 12 Late mins = 120
# Evals: 27
# Improved (146) Missing staff = 36 Late = 11 Late mins = 110
# Evals: 29
# Improved (135) Missing staff = 35 Late = 10 Late mins = 100
# Evals: 34
# Improved (127) Missing staff = 37 Late = 9 Late mins = 90
# Evals: 57
# Improved (126) Missing staff = 36 Late = 9 Late mins = 90
# Evals: 77
# Improved (125) Missing staff = 35 Late = 9 Late mins = 90
# Run 5 - Done: 125
#
# Running for aircrafts_sample_56 instance
# Run 1 - Init
# Initial best: 149
# Evals: 9
# Improved (141) Missing staff = 41 Late = 10 Late mins = 100
# Evals: 14
# Improved (136) Missing staff = 46 Late = 9 Late mins = 90
# Evals: 23
# Improved (124) Missing staff = 44 Late = 8 Late mins = 80
# Evals: 32
# Improved (123) Missing staff = 43 Late = 8 Late mins = 80
# Evals: 53
# Improved (121) Missing staff = 41 Late = 8 Late mins = 80
# Run 1 - Done: 121
#
# Run 2 - Init
# Initial best: 138
# Evals: 4
# Improved (134) Missing staff = 64 Late = 7 Late mins = 70
# Evals: 18
# Improved (128) Missing staff = 58 Late = 7 Late mins = 70
# Evals: 36
# Improved (122) Missing staff = 62 Late = 6 Late mins = 60
# Evals: 46
# Improved (114) Missing staff = 64 Late = 5 Late mins = 50
# Evals: 49
# Improved (106) Missing staff = 56 Late = 5 Late mins = 50
# Run 2 - Done: 106
#
# Run 3 - Init
# Initial best: 135
# Evals: 11
# Improved (128) Missing staff = 38 Late = 9 Late mins = 90
# Evals: 83
# Improved (122) Missing staff = 52 Late = 7 Late mins = 70
# Evals: 85
# Improved (120) Missing staff = 50 Late = 7 Late mins = 70
# Evals: 97
# Improved (111) Missing staff = 51 Late = 6 Late mins = 60
# Run 3 - Done: 111
#
# Run 4 - Init
# Initial best: 139
# Evals: 11
# Improved (125) Missing staff = 35 Late = 9 Late mins = 90
# Evals: 15
# Improved (124) Missing staff = 34 Late = 9 Late mins = 90
# Evals: 16
# Improved (122) Missing staff = 32 Late = 9 Late mins = 90
# Evals: 71
# Improved (121) Missing staff = 31 Late = 9 Late mins = 90
# Evals: 93
# Improved (120) Missing staff = 30 Late = 9 Late mins = 90
# Evals: 100
# Improved (119) Missing staff = 29 Late = 9 Late mins = 90
# Run 4 - Done: 119
#
# Run 5 - Init
# Initial best: 145
# Evals: 8
# Improved (137) Missing staff = 47 Late = 9 Late mins = 90
# Evals: 12
# Improved (133) Missing staff = 43 Late = 9 Late mins = 90
# Evals: 31
# Improved (109) Missing staff = 39 Late = 7 Late mins = 70
# Evals: 32
# Improved (102) Missing staff = 42 Late = 6 Late mins = 60
# Evals: 48
# Improved (101) Missing staff = 41 Late = 6 Late mins = 60
# Run 5 - Done: 101
#
# Running for aircrafts_sample_68 instance
# Run 1 - Init
# Initial best: 94
# Evals: 2
# Improved (93) Missing staff = 43 Late = 5 Late mins = 50
# Evals: 8
# Improved (82) Missing staff = 42 Late = 4 Late mins = 40
# Evals: 23
# Improved (72) Missing staff = 42 Late = 3 Late mins = 30
# Evals: 34
# Improved (63) Missing staff = 33 Late = 3 Late mins = 30
# Evals: 43
# Improved (61) Missing staff = 31 Late = 3 Late mins = 30
# Evals: 44
# Improved (60) Missing staff = 30 Late = 3 Late mins = 30
# Evals: 63
# Improved (58) Missing staff = 28 Late = 3 Late mins = 30
# Evals: 83
# Improved (57) Missing staff = 27 Late = 3 Late mins = 30
# Run 1 - Done: 57
#
# Run 2 - Init
# Initial best: 98
# Evals: 9
# Improved (96) Missing staff = 46 Late = 5 Late mins = 50
# Evals: 19
# Improved (95) Missing staff = 45 Late = 5 Late mins = 50
# Evals: 34
# Improved (89) Missing staff = 49 Late = 4 Late mins = 40
# Evals: 89
# Improved (88) Missing staff = 48 Late = 4 Late mins = 40
# Run 2 - Done: 88
#
# Run 3 - Init
# Initial best: 102
# Evals: 1
# Improved (86) Missing staff = 46 Late = 4 Late mins = 40
# Evals: 11
# Improved (79) Missing staff = 49 Late = 3 Late mins = 30
# Evals: 14
# Improved (71) Missing staff = 51 Late = 2 Late mins = 20
# Evals: 28
# Improved (69) Missing staff = 49 Late = 2 Late mins = 20
# Evals: 98
# Improved (67) Missing staff = 47 Late = 2 Late mins = 20
# Run 3 - Done: 67
#
# Run 4 - Init
# Initial best: 95
# Evals: 13
# Improved (93) Missing staff = 43 Late = 5 Late mins = 50
# Evals: 15
# Improved (80) Missing staff = 50 Late = 3 Late mins = 30
# Evals: 18
# Improved (71) Missing staff = 51 Late = 2 Late mins = 20
# Evals: 27
# Improved (70) Missing staff = 50 Late = 2 Late mins = 20
# Evals: 72
# Improved (69) Missing staff = 49 Late = 2 Late mins = 20
# Evals: 87
# Improved (68) Missing staff = 48 Late = 2 Late mins = 20
# Run 4 - Done: 68
#
# Run 5 - Init
# Initial best: 103
# Evals: 23
# Improved (93) Missing staff = 43 Late = 5 Late mins = 50
# Evals: 25
# Improved (92) Missing staff = 42 Late = 5 Late mins = 50
# Evals: 33
# Improved (91) Missing staff = 41 Late = 5 Late mins = 50
# Evals: 43
# Improved (81) Missing staff = 41 Late = 4 Late mins = 40
# Evals: 57
# Improved (80) Missing staff = 40 Late = 4 Late mins = 40
# Evals: 66
# Improved (79) Missing staff = 39 Late = 4 Late mins = 40
# Evals: 86
# Improved (78) Missing staff = 38 Late = 4 Late mins = 40
# Run 5 - Done: 78
#
# Running for aircrafts_sample_40 instance
# Run 1 - Init
# Initial best: 138
# Evals: 12
# Improved (135) Missing staff = 35 Late = 10 Late mins = 100
# Evals: 14
# Improved (133) Missing staff = 43 Late = 9 Late mins = 90
# Evals: 15
# Improved (129) Missing staff = 49 Late = 8 Late mins = 80
# Evals: 51
# Improved (128) Missing staff = 48 Late = 8 Late mins = 80
# Evals: 52
# Improved (127) Missing staff = 47 Late = 8 Late mins = 80
# Evals: 57
# Improved (126) Missing staff = 56 Late = 7 Late mins = 70
# Evals: 63
# Improved (124) Missing staff = 54 Late = 7 Late mins = 70
# Evals: 64
# Improved (117) Missing staff = 47 Late = 7 Late mins = 70
# Evals: 70
# Improved (116) Missing staff = 46 Late = 7 Late mins = 70
# Evals: 84
# Improved (115) Missing staff = 45 Late = 7 Late mins = 70
# Evals: 92
# Improved (114) Missing staff = 44 Late = 7 Late mins = 70
# Evals: 93
# Improved (113) Missing staff = 43 Late = 7 Late mins = 70
# Evals: 100
# Improved (107) Missing staff = 37 Late = 7 Late mins = 70
# Run 1 - Done: 107
#
# Run 2 - Init
# Initial best: 133
# Evals: 40
# Improved (123) Missing staff = 63 Late = 6 Late mins = 60
# Evals: 45
# Improved (122) Missing staff = 62 Late = 6 Late mins = 60
# Evals: 59
# Improved (121) Missing staff = 61 Late = 6 Late mins = 60
# Evals: 72
# Improved (119) Missing staff = 49 Late = 7 Late mins = 70
# Evals: 90
# Improved (113) Missing staff = 63 Late = 5 Late mins = 50
# Run 2 - Done: 113
#
# Run 3 - Init
# Initial best: 113
# Evals: 44
# Improved (112) Missing staff = 52 Late = 6 Late mins = 60
# Evals: 72
# Improved (111) Missing staff = 41 Late = 7 Late mins = 70
# Evals: 96
# Improved (110) Missing staff = 40 Late = 7 Late mins = 70
# Run 3 - Done: 110
#
# Run 4 - Init
# Initial best: 114
# Evals: 10
# Improved (110) Missing staff = 60 Late = 5 Late mins = 50
# Evals: 54
# Improved (101) Missing staff = 61 Late = 4 Late mins = 40
# Evals: 86
# Improved (98) Missing staff = 58 Late = 4 Late mins = 40
# Evals: 93
# Improved (97) Missing staff = 57 Late = 4 Late mins = 40
# Run 4 - Done: 97
#
# Run 5 - Init
# Initial best: 108
# Evals: 7
# Improved (103) Missing staff = 33 Late = 7 Late mins = 70
# Evals: 50
# Improved (97) Missing staff = 47 Late = 5 Late mins = 50
# Evals: 64
# Improved (96) Missing staff = 46 Late = 5 Late mins = 50
# Evals: 69
# Improved (95) Missing staff = 45 Late = 5 Late mins = 50
# Run 5 - Done: 95
#
# Running for aircrafts_sample_54 instance
# Run 1 - Init
# Initial best: 127
# Evals: 36
# Improved (126) Missing staff = 46 Late = 8 Late mins = 80
# Evals: 50
# Improved (125) Missing staff = 45 Late = 8 Late mins = 80
# Evals: 75
# Improved (124) Missing staff = 44 Late = 8 Late mins = 80
# Run 1 - Done: 124
#
# Run 2 - Init
# Initial best: 117
# Evals: 32
# Improved (109) Missing staff = 39 Late = 7 Late mins = 70
# Evals: 54
# Improved (107) Missing staff = 37 Late = 7 Late mins = 70
# Evals: 94
# Improved (106) Missing staff = 36 Late = 7 Late mins = 70
# Run 2 - Done: 106
#
# Run 3 - Init
# Initial best: 140
# Evals: 6
# Improved (134) Missing staff = 54 Late = 8 Late mins = 80
# Evals: 16
# Improved (132) Missing staff = 52 Late = 8 Late mins = 80
# Evals: 45
# Improved (121) Missing staff = 51 Late = 7 Late mins = 70
# Evals: 55
# Improved (120) Missing staff = 50 Late = 7 Late mins = 70
# Evals: 97
# Improved (111) Missing staff = 51 Late = 6 Late mins = 60
# Run 3 - Done: 111
#
# Run 4 - Init
# Initial best: 126
# Evals: 20
# Improved (121) Missing staff = 41 Late = 8 Late mins = 80
# Evals: 83
# Improved (120) Missing staff = 40 Late = 8 Late mins = 80
# Run 4 - Done: 120
#
# Run 5 - Init
# Initial best: 107
# Evals: 26
# Improved (106) Missing staff = 36 Late = 7 Late mins = 70
# Evals: 53
# Improved (105) Missing staff = 35 Late = 7 Late mins = 70
# Evals: 86
# Improved (104) Missing staff = 34 Late = 7 Late mins = 70
# Run 5 - Done: 104
#
# Running for aircrafts_instance_1 instance
# Run 1 - Init
# Initial best: 106
# Evals: 30
# Improved (101) Missing staff = 31 Late = 7 Late mins = 70
# Evals: 34
# Improved (100) Missing staff = 30 Late = 7 Late mins = 70
# Evals: 59
# Improved (99) Missing staff = 29 Late = 7 Late mins = 70
# Evals: 70
# Improved (91) Missing staff = 31 Late = 6 Late mins = 60
# Run 1 - Done: 91
#
# Run 2 - Init
# Initial best: 104
# Evals: 26
# Improved (97) Missing staff = 37 Late = 6 Late mins = 60
# Evals: 56
# Improved (93) Missing staff = 33 Late = 6 Late mins = 60
# Evals: 98
# Improved (91) Missing staff = 31 Late = 6 Late mins = 60
# Run 2 - Done: 91
#
# Run 3 - Init
# Initial best: 130
# Evals: 22
# Improved (110) Missing staff = 30 Late = 8 Late mins = 80
# Evals: 39
# Improved (97) Missing staff = 37 Late = 6 Late mins = 60
# Evals: 60
# Improved (94) Missing staff = 44 Late = 5 Late mins = 50
# Evals: 64
# Improved (86) Missing staff = 36 Late = 5 Late mins = 50
# Evals: 81
# Improved (80) Missing staff = 30 Late = 5 Late mins = 50
# Run 3 - Done: 80
#
# Run 4 - Init
# Initial best: 126
# Evals: 5
# Improved (125) Missing staff = 25 Late = 10 Late mins = 100
# Evals: 8
# Improved (115) Missing staff = 25 Late = 9 Late mins = 90
# Evals: 14
# Improved (105) Missing staff = 15 Late = 9 Late mins = 90
# Evals: 43
# Improved (99) Missing staff = 19 Late = 8 Late mins = 80
# Evals: 56
# Improved (88) Missing staff = 18 Late = 7 Late mins = 70
# Evals: 61
# Improved (81) Missing staff = 21 Late = 6 Late mins = 60
# Run 4 - Done: 81
#
# Run 5 - Init
# Initial best: 132
# Evals: 25
# Improved (120) Missing staff = 30 Late = 9 Late mins = 90
# Evals: 27
# Improved (114) Missing staff = 34 Late = 8 Late mins = 80
# Evals: 28
# Improved (97) Missing staff = 47 Late = 5 Late mins = 50
# Evals: 57
# Improved (96) Missing staff = 46 Late = 5 Late mins = 50
# Evals: 60
# Improved (87) Missing staff = 47 Late = 4 Late mins = 40
# Evals: 89
# Improved (84) Missing staff = 44 Late = 4 Late mins = 40
# Evals: 96
# Improved (82) Missing staff = 42 Late = 4 Late mins = 40
# Run 5 - Done: 82
#
# Running for aircrafts_sample_1 instance
# Run 1 - Init
# Initial best: 128
# Evals: 7
# Improved (125) Missing staff = 45 Late = 8 Late mins = 80
# Evals: 8
# Improved (121) Missing staff = 51 Late = 7 Late mins = 70
# Evals: 11
# Improved (120) Missing staff = 50 Late = 7 Late mins = 70
# Evals: 22
# Improved (115) Missing staff = 45 Late = 7 Late mins = 70
# Evals: 48
# Improved (104) Missing staff = 34 Late = 7 Late mins = 70
# Evals: 72
# Improved (103) Missing staff = 33 Late = 7 Late mins = 70
# Evals: 91
# Improved (95) Missing staff = 35 Late = 6 Late mins = 60
# Run 1 - Done: 95
#
# Run 2 - Init
# Initial best: 98
# Evals: 22
# Improved (96) Missing staff = 46 Late = 5 Late mins = 50
# Evals: 43
# Improved (95) Missing staff = 45 Late = 5 Late mins = 50
# Evals: 57
# Improved (94) Missing staff = 44 Late = 5 Late mins = 50
# Evals: 84
# Improved (92) Missing staff = 42 Late = 5 Late mins = 50
# Run 2 - Done: 92
#
# Run 3 - Init
# Initial best: 103
# Evals: 19
# Improved (102) Missing staff = 42 Late = 6 Late mins = 60
# Evals: 20
# Improved (95) Missing staff = 35 Late = 6 Late mins = 60
# Evals: 33
# Improved (94) Missing staff = 34 Late = 6 Late mins = 60
# Evals: 37
# Improved (90) Missing staff = 30 Late = 6 Late mins = 60
# Evals: 42
# Improved (85) Missing staff = 35 Late = 5 Late mins = 50
# Evals: 51
# Improved (80) Missing staff = 30 Late = 5 Late mins = 50
# Evals: 96
# Improved (79) Missing staff = 29 Late = 5 Late mins = 50
# Run 3 - Done: 79
#
# Run 4 - Init
# Initial best: 127
# Evals: 7
# Improved (125) Missing staff = 55 Late = 7 Late mins = 70
# Evals: 15
# Improved (123) Missing staff = 53 Late = 7 Late mins = 70
# Evals: 19
# Improved (122) Missing staff = 52 Late = 7 Late mins = 70
# Evals: 27
# Improved (120) Missing staff = 50 Late = 7 Late mins = 70
# Evals: 46
# Improved (117) Missing staff = 47 Late = 7 Late mins = 70
# Evals: 70
# Improved (116) Missing staff = 46 Late = 7 Late mins = 70
# Evals: 82
# Improved (115) Missing staff = 45 Late = 7 Late mins = 70
# Run 4 - Done: 115
#
# Run 5 - Init
# Initial best: 121
# Evals: 45
# Improved (112) Missing staff = 52 Late = 6 Late mins = 60
# Evals: 66
# Improved (108) Missing staff = 48 Late = 6 Late mins = 60
# Evals: 99
# Improved (98) Missing staff = 48 Late = 5 Late mins = 50
# Run 5 - Done: 98
#
# Running for aircrafts_sample_55 instance
# Run 1 - Init
# Initial best: 125
# Evals: 6
# Improved (111) Missing staff = 31 Late = 8 Late mins = 80
# Evals: 9
# Improved (102) Missing staff = 32 Late = 7 Late mins = 70
# Evals: 36
# Improved (92) Missing staff = 22 Late = 7 Late mins = 70
# Evals: 40
# Improved (85) Missing staff = 25 Late = 6 Late mins = 60
# Evals: 51
# Improved (84) Missing staff = 24 Late = 6 Late mins = 60
# Evals: 69
# Improved (83) Missing staff = 23 Late = 6 Late mins = 60
# Run 1 - Done: 83
#
# Run 2 - Init
# Initial best: 145
# Evals: 3
# Improved (135) Missing staff = 45 Late = 9 Late mins = 90
# Evals: 5
# Improved (129) Missing staff = 49 Late = 8 Late mins = 80
# Evals: 35
# Improved (127) Missing staff = 47 Late = 8 Late mins = 80
# Evals: 74
# Improved (126) Missing staff = 46 Late = 8 Late mins = 80
# Evals: 82
# Improved (122) Missing staff = 42 Late = 8 Late mins = 80
# Evals: 92
# Improved (121) Missing staff = 41 Late = 8 Late mins = 80
# Run 2 - Done: 121
#
# Run 3 - Init
# Initial best: 142
# Evals: 9
# Improved (140) Missing staff = 30 Late = 11 Late mins = 110
# Evals: 10
# Improved (133) Missing staff = 33 Late = 10 Late mins = 100
# Evals: 14
# Improved (117) Missing staff = 17 Late = 10 Late mins = 100
# Evals: 68
# Improved (116) Missing staff = 16 Late = 10 Late mins = 100
# Evals: 69
# Improved (110) Missing staff = 20 Late = 9 Late mins = 90
# Evals: 75
# Improved (100) Missing staff = 20 Late = 8 Late mins = 80
# Run 3 - Done: 100
#
# Run 4 - Init
# Initial best: 123
# Evals: 31
# Improved (121) Missing staff = 31 Late = 9 Late mins = 90
# Evals: 51
# Improved (120) Missing staff = 40 Late = 8 Late mins = 80
# Evals: 95
# Improved (117) Missing staff = 37 Late = 8 Late mins = 80
# Run 4 - Done: 117
#
# Run 5 - Init
# Initial best: 135
# Evals: 29
# Improved (134) Missing staff = 34 Late = 10 Late mins = 100
# Evals: 51
# Improved (133) Missing staff = 33 Late = 10 Late mins = 100
# Evals: 72
# Improved (132) Missing staff = 32 Late = 10 Late mins = 100
# Evals: 81
# Improved (131) Missing staff = 31 Late = 10 Late mins = 100
# Evals: 82
# Improved (130) Missing staff = 30 Late = 10 Late mins = 100
# Evals: 88
# Improved (122) Missing staff = 32 Late = 9 Late mins = 90
# Run 5 - Done: 122
#
# Running for aircrafts_sample_41 instance
# Run 1 - Init
# Initial best: 147
# Evals: 7
# Improved (145) Missing staff = 45 Late = 10 Late mins = 100
# Evals: 10
# Improved (137) Missing staff = 47 Late = 9 Late mins = 90
# Evals: 29
# Improved (134) Missing staff = 54 Late = 8 Late mins = 80
# Evals: 73
# Improved (125) Missing staff = 55 Late = 7 Late mins = 70
# Evals: 77
# Improved (115) Missing staff = 45 Late = 7 Late mins = 70
# Run 1 - Done: 115
#
# Run 2 - Init
# Initial best: 135
# Evals: 10
# Improved (134) Missing staff = 44 Late = 9 Late mins = 90
# Evals: 27
# Improved (133) Missing staff = 53 Late = 8 Late mins = 80
# Evals: 29
# Improved (132) Missing staff = 52 Late = 8 Late mins = 80
# Evals: 37
# Improved (127) Missing staff = 47 Late = 8 Late mins = 80
# Evals: 43
# Improved (120) Missing staff = 50 Late = 7 Late mins = 70
# Evals: 60
# Improved (115) Missing staff = 45 Late = 7 Late mins = 70
# Evals: 68
# Improved (108) Missing staff = 48 Late = 6 Late mins = 60
# Run 2 - Done: 108
#
# Run 3 - Init
# Initial best: 121
# Evals: 2
# Improved (119) Missing staff = 39 Late = 8 Late mins = 80
# Evals: 5
# Improved (118) Missing staff = 38 Late = 8 Late mins = 80
# Evals: 11
# Improved (108) Missing staff = 68 Late = 4 Late mins = 40
# Evals: 45
# Improved (105) Missing staff = 65 Late = 4 Late mins = 40
# Evals: 63
# Improved (102) Missing staff = 62 Late = 4 Late mins = 40
# Evals: 79
# Improved (100) Missing staff = 60 Late = 4 Late mins = 40
# Evals: 80
# Improved (98) Missing staff = 58 Late = 4 Late mins = 40
# Evals: 85
# Improved (96) Missing staff = 56 Late = 4 Late mins = 40
# Evals: 96
# Improved (84) Missing staff = 54 Late = 3 Late mins = 30
# Run 3 - Done: 84
#
# Run 4 - Init
# Initial best: 141
# Evals: 1
# Improved (122) Missing staff = 42 Late = 8 Late mins = 80
# Evals: 4
# Improved (121) Missing staff = 41 Late = 8 Late mins = 80
# Evals: 25
# Improved (120) Missing staff = 40 Late = 8 Late mins = 80
# Evals: 28
# Improved (112) Missing staff = 42 Late = 7 Late mins = 70
# Evals: 29
# Improved (106) Missing staff = 36 Late = 7 Late mins = 70
# Evals: 69
# Improved (97) Missing staff = 37 Late = 6 Late mins = 60
# Evals: 87
# Improved (96) Missing staff = 36 Late = 6 Late mins = 60
# Run 4 - Done: 96
#
# Run 5 - Init
# Initial best: 134
# Evals: 5
# Improved (127) Missing staff = 57 Late = 7 Late mins = 70
# Evals: 25
# Improved (125) Missing staff = 55 Late = 7 Late mins = 70
# Evals: 27
# Improved (122) Missing staff = 52 Late = 7 Late mins = 70
# Evals: 40
# Improved (116) Missing staff = 46 Late = 7 Late mins = 70
# Evals: 78
# Improved (115) Missing staff = 45 Late = 7 Late mins = 70
# Evals: 83
# Improved (112) Missing staff = 52 Late = 6 Late mins = 60
# Run 5 - Done: 112
#
# Running for aircrafts_sample_69 instance
# Run 1 - Init
# Initial best: 136
# Evals: 9
# Improved (135) Missing staff = 35 Late = 10 Late mins = 100
# Evals: 59
# Improved (134) Missing staff = 34 Late = 10 Late mins = 100
# Evals: 69
# Improved (133) Missing staff = 33 Late = 10 Late mins = 100
# Evals: 73
# Improved (129) Missing staff = 29 Late = 10 Late mins = 100
# Run 1 - Done: 129
#
# Run 2 - Init
# Initial best: 121
# Evals: 12
# Improved (120) Missing staff = 40 Late = 8 Late mins = 80
# Evals: 13
# Improved (116) Missing staff = 36 Late = 8 Late mins = 80
# Evals: 56
# Improved (115) Missing staff = 35 Late = 8 Late mins = 80
# Evals: 76
# Improved (111) Missing staff = 41 Late = 7 Late mins = 70
# Evals: 92
# Improved (108) Missing staff = 38 Late = 7 Late mins = 70
# Run 2 - Done: 108
#
# Run 3 - Init
# Initial best: 119
# Evals: 46
# Improved (118) Missing staff = 48 Late = 7 Late mins = 70
# Evals: 55
# Improved (117) Missing staff = 47 Late = 7 Late mins = 70
# Evals: 69
# Improved (114) Missing staff = 44 Late = 7 Late mins = 70
# Run 3 - Done: 114
#
# Run 4 - Init
# Initial best: 101
# Evals: 69
# Improved (100) Missing staff = 40 Late = 6 Late mins = 60
# Evals: 77
# Improved (92) Missing staff = 42 Late = 5 Late mins = 50
# Evals: 100
# Improved (91) Missing staff = 41 Late = 5 Late mins = 50
# Run 4 - Done: 91
#
# Run 5 - Init
# Initial best: 116
# Evals: 32
# Improved (100) Missing staff = 30 Late = 7 Late mins = 70
# Run 5 - Done: 100
#
# Running for aircrafts_sample_45 instance
# Run 1 - Init
# Initial best: 110
# Evals: 13
# Improved (109) Missing staff = 29 Late = 8 Late mins = 80
# Evals: 51
# Improved (108) Missing staff = 28 Late = 8 Late mins = 80
# Evals: 61
# Improved (107) Missing staff = 27 Late = 8 Late mins = 80
# Run 1 - Done: 107
#
# Run 2 - Init
# Initial best: 116
# Evals: 10
# Improved (111) Missing staff = 31 Late = 8 Late mins = 80
# Evals: 16
# Improved (107) Missing staff = 27 Late = 8 Late mins = 80
# Evals: 40
# Improved (97) Missing staff = 27 Late = 7 Late mins = 70
# Evals: 63
# Improved (94) Missing staff = 24 Late = 7 Late mins = 70
# Run 2 - Done: 94
#
# Run 3 - Init
# Initial best: 130
# Evals: 6
# Improved (127) Missing staff = 47 Late = 8 Late mins = 80
# Evals: 15
# Improved (120) Missing staff = 40 Late = 8 Late mins = 80
# Evals: 17
# Improved (118) Missing staff = 28 Late = 9 Late mins = 90
# Evals: 19
# Improved (108) Missing staff = 28 Late = 8 Late mins = 80
# Evals: 23
# Improved (105) Missing staff = 25 Late = 8 Late mins = 80
# Evals: 29
# Improved (102) Missing staff = 22 Late = 8 Late mins = 80
# Evals: 31
# Improved (92) Missing staff = 22 Late = 7 Late mins = 70
# Evals: 51
# Improved (91) Missing staff = 21 Late = 7 Late mins = 70
# Evals: 64
# Improved (88) Missing staff = 18 Late = 7 Late mins = 70
# Evals: 68
# Improved (86) Missing staff = 16 Late = 7 Late mins = 70
# Run 3 - Done: 86
#
# Run 4 - Init
# Initial best: 119
# Evals: 22
# Improved (111) Missing staff = 41 Late = 7 Late mins = 70
# Evals: 23
# Improved (110) Missing staff = 40 Late = 7 Late mins = 70
# Evals: 51
# Improved (109) Missing staff = 39 Late = 7 Late mins = 70
# Evals: 72
# Improved (108) Missing staff = 38 Late = 7 Late mins = 70
# Run 4 - Done: 108
#
# Run 5 - Init
# Initial best: 110
# Evals: 8
# Improved (100) Missing staff = 30 Late = 7 Late mins = 70
# Evals: 22
# Improved (99) Missing staff = 29 Late = 7 Late mins = 70
# Evals: 41
# Improved (98) Missing staff = 28 Late = 7 Late mins = 70
# Evals: 78
# Improved (92) Missing staff = 32 Late = 6 Late mins = 60
# Evals: 83
# Improved (91) Missing staff = 31 Late = 6 Late mins = 60
# Evals: 89
# Improved (87) Missing staff = 27 Late = 6 Late mins = 60
# Evals: 95
# Improved (85) Missing staff = 25 Late = 6 Late mins = 60
# Run 5 - Done: 85
#
# Running for aircrafts_sample_51 instance
# Run 1 - Init
# Initial best: 145
# Evals: 14
# Improved (137) Missing staff = 47 Late = 9 Late mins = 90
# Evals: 21
# Improved (136) Missing staff = 46 Late = 9 Late mins = 90
# Evals: 28
# Improved (130) Missing staff = 50 Late = 8 Late mins = 80
# Evals: 30
# Improved (129) Missing staff = 39 Late = 9 Late mins = 90
# Evals: 40
# Improved (128) Missing staff = 38 Late = 9 Late mins = 90
# Evals: 82
# Improved (124) Missing staff = 34 Late = 9 Late mins = 90
# Run 1 - Done: 124
#
# Run 2 - Init
# Initial best: 140
# Evals: 5
# Improved (136) Missing staff = 16 Late = 12 Late mins = 120
# Evals: 26
# Improved (135) Missing staff = 15 Late = 12 Late mins = 120
# Evals: 67
# Improved (133) Missing staff = 13 Late = 12 Late mins = 120
# Evals: 69
# Improved (126) Missing staff = 16 Late = 11 Late mins = 110
# Evals: 74
# Improved (125) Missing staff = 15 Late = 11 Late mins = 110
# Evals: 85
# Improved (124) Missing staff = 14 Late = 11 Late mins = 110
# Run 2 - Done: 124
#
# Run 3 - Init
# Initial best: 145
# Evals: 15
# Improved (144) Missing staff = 34 Late = 11 Late mins = 110
# Evals: 16
# Improved (138) Missing staff = 58 Late = 8 Late mins = 80
# Evals: 20
# Improved (106) Missing staff = 36 Late = 7 Late mins = 70
# Evals: 44
# Improved (103) Missing staff = 33 Late = 7 Late mins = 70
# Evals: 52
# Improved (102) Missing staff = 32 Late = 7 Late mins = 70
# Evals: 56
# Improved (100) Missing staff = 40 Late = 6 Late mins = 60
# Evals: 73
# Improved (99) Missing staff = 39 Late = 6 Late mins = 60
# Evals: 80
# Improved (98) Missing staff = 38 Late = 6 Late mins = 60
# Evals: 81
# Improved (97) Missing staff = 37 Late = 6 Late mins = 60
# Evals: 94
# Improved (95) Missing staff = 35 Late = 6 Late mins = 60
# Evals: 96
# Improved (94) Missing staff = 34 Late = 6 Late mins = 60
# Run 3 - Done: 94
#
# Run 4 - Init
# Initial best: 135
# Evals: 15
# Improved (134) Missing staff = 44 Late = 9 Late mins = 90
# Evals: 20
# Improved (124) Missing staff = 34 Late = 9 Late mins = 90
# Evals: 40
# Improved (123) Missing staff = 33 Late = 9 Late mins = 90
# Evals: 53
# Improved (122) Missing staff = 32 Late = 9 Late mins = 90
# Evals: 69
# Improved (118) Missing staff = 28 Late = 9 Late mins = 90
# Evals: 81
# Improved (117) Missing staff = 27 Late = 9 Late mins = 90
# Evals: 83
# Improved (116) Missing staff = 26 Late = 9 Late mins = 90
# Evals: 87
# Improved (115) Missing staff = 25 Late = 9 Late mins = 90
# Run 4 - Done: 115
#
# Run 5 - Init
# Initial best: 137
# Evals: 32
# Improved (126) Missing staff = 36 Late = 9 Late mins = 90
# Evals: 42
# Improved (125) Missing staff = 35 Late = 9 Late mins = 90
# Evals: 60
# Improved (116) Missing staff = 36 Late = 8 Late mins = 80
# Evals: 71
# Improved (115) Missing staff = 35 Late = 8 Late mins = 80
# Evals: 78
# Improved (114) Missing staff = 34 Late = 8 Late mins = 80
# Evals: 99
# Improved (113) Missing staff = 33 Late = 8 Late mins = 80
# Run 5 - Done: 113
#
# Running for aircrafts_sample_79 instance
# Run 1 - Init
# Initial best: 109
# Evals: 39
# Improved (108) Missing staff = 28 Late = 8 Late mins = 80
# Evals: 54
# Improved (98) Missing staff = 28 Late = 7 Late mins = 70
# Evals: 55
# Improved (97) Missing staff = 27 Late = 7 Late mins = 70
# Evals: 83
# Improved (95) Missing staff = 25 Late = 7 Late mins = 70
# Run 1 - Done: 95
#
# Run 2 - Init
# Initial best: 114
# Evals: 2
# Improved (104) Missing staff = 24 Late = 8 Late mins = 80
# Evals: 17
# Improved (99) Missing staff = 29 Late = 7 Late mins = 70
# Evals: 39
# Improved (97) Missing staff = 27 Late = 7 Late mins = 70
# Evals: 45
# Improved (96) Missing staff = 26 Late = 7 Late mins = 70
# Evals: 62
# Improved (91) Missing staff = 31 Late = 6 Late mins = 60
# Run 2 - Done: 91
#
# Run 3 - Init
# Initial best: 135
# Evals: 6
# Improved (129) Missing staff = 49 Late = 8 Late mins = 80
# Evals: 10
# Improved (126) Missing staff = 46 Late = 8 Late mins = 80
# Evals: 21
# Improved (125) Missing staff = 45 Late = 8 Late mins = 80
# Evals: 24
# Improved (115) Missing staff = 35 Late = 8 Late mins = 80
# Evals: 55
# Improved (110) Missing staff = 40 Late = 7 Late mins = 70
# Evals: 60
# Improved (108) Missing staff = 38 Late = 7 Late mins = 70
# Evals: 68
# Improved (107) Missing staff = 37 Late = 7 Late mins = 70
# Evals: 74
# Improved (106) Missing staff = 36 Late = 7 Late mins = 70
# Evals: 85
# Improved (104) Missing staff = 34 Late = 7 Late mins = 70
# Evals: 87
# Improved (97) Missing staff = 37 Late = 6 Late mins = 60
# Evals: 100
# Improved (95) Missing staff = 35 Late = 6 Late mins = 60
# Run 3 - Done: 95
#
# Run 4 - Init
# Initial best: 121
# Evals: 9
# Improved (119) Missing staff = 49 Late = 7 Late mins = 70
# Evals: 10
# Improved (114) Missing staff = 44 Late = 7 Late mins = 70
# Evals: 26
# Improved (106) Missing staff = 46 Late = 6 Late mins = 60
# Evals: 29
# Improved (96) Missing staff = 46 Late = 5 Late mins = 50
# Evals: 37
# Improved (90) Missing staff = 40 Late = 5 Late mins = 50
# Evals: 78
# Improved (88) Missing staff = 38 Late = 5 Late mins = 50
# Evals: 80
# Improved (83) Missing staff = 33 Late = 5 Late mins = 50
# Evals: 94
# ...
# Evals: 16
# Improved (125) Missing staff = 55 Late = 7 Late mins = 70
# Evals: 27
# Improved (124) Missing staff = 54 Late = 7 Late mins = 70
# Evals: 30
# Improved (110) Missing staff = 50 Late = 6 Late mins = 60
# Evals: 33
# Improved (103) Missing staff = 43 Late = 6 Late mins = 60
# Evals: 48
# Improved (102) Missing staff = 52 Late = 5 Late mins = 50
# Evals: 66
# Improved (101) Missing staff = 51 Late = 5 Late mins = 50
# Evals: 70
# Improved (100) Missing staff = 50 Late = 5 Late mins = 50
# Evals: 71
# Improved (94) Missing staff = 44 Late = 5 Late mins = 50
# Evals: 90
# Improved (92) Missing staff = 42 Late = 5 Late mins = 50
# Run 1 - Done: 92
#
# Run 2 - Init
# Initial best: 128
# Evals: 1
# Improved (125) Missing staff = 55 Late = 7 Late mins = 70
# Evals: 20
# Improved (119) Missing staff = 49 Late = 7 Late mins = 70
# Evals: 28
# Improved (118) Missing staff = 48 Late = 7 Late mins = 70
# Evals: 33
# Improved (115) Missing staff = 55 Late = 6 Late mins = 60
# Evals: 51
# Improved (110) Missing staff = 50 Late = 6 Late mins = 60
# Evals: 57
# Improved (108) Missing staff = 48 Late = 6 Late mins = 60
# Evals: 66
# Improved (102) Missing staff = 42 Late = 6 Late mins = 60
# Evals: 71
# Improved (101) Missing staff = 41 Late = 6 Late mins = 60
# Run 2 - Done: 101
#
# Run 3 - Init
# Initial best: 123
# Evals: 19
# Improved (98) Missing staff = 38 Late = 6 Late mins = 60
# Evals: 29
# Improved (94) Missing staff = 44 Late = 5 Late mins = 50
# Evals: 58
# Improved (86) Missing staff = 46 Late = 4 Late mins = 40
# Evals: 63
# Improved (85) Missing staff = 45 Late = 4 Late mins = 40
# Evals: 97
# Improved (83) Missing staff = 43 Late = 4 Late mins = 40
# Run 3 - Done: 83
#
# Run 4 - Init
# Initial best: 110
# Evals: 8
# Improved (106) Missing staff = 36 Late = 7 Late mins = 70
# Evals: 39
# Improved (102) Missing staff = 32 Late = 7 Late mins = 70
# Evals: 48
# Improved (100) Missing staff = 30 Late = 7 Late mins = 70
# Evals: 50
# Improved (99) Missing staff = 29 Late = 7 Late mins = 70
# Evals: 52
# Improved (91) Missing staff = 31 Late = 6 Late mins = 60
# Run 4 - Done: 91
#
# Run 5 - Init
# Initial best: 121
# Evals: 23
# Improved (117) Missing staff = 47 Late = 7 Late mins = 70
# Evals: 63
# Improved (116) Missing staff = 46 Late = 7 Late mins = 70
# Evals: 75
# Improved (113) Missing staff = 43 Late = 7 Late mins = 70
# Run 5 - Done: 113
#
# Running for aircrafts_sample_73 instance
# Run 1 - Init
# Initial best: 147
# Evals: 3
# Improved (143) Missing staff = 53 Late = 9 Late mins = 90
# Evals: 11
# Improved (135) Missing staff = 45 Late = 9 Late mins = 90
# Evals: 17
# Improved (126) Missing staff = 46 Late = 8 Late mins = 80
# Evals: 29
# Improved (118) Missing staff = 48 Late = 7 Late mins = 70
# Evals: 33
# Improved (115) Missing staff = 45 Late = 7 Late mins = 70
# Evals: 37
# Improved (112) Missing staff = 42 Late = 7 Late mins = 70
# Evals: 43
# Improved (109) Missing staff = 39 Late = 7 Late mins = 70
# Evals: 53
# Improved (107) Missing staff = 47 Late = 6 Late mins = 60
# Evals: 75
# Improved (106) Missing staff = 46 Late = 6 Late mins = 60
# Evals: 81
# Improved (104) Missing staff = 44 Late = 6 Late mins = 60
# Evals: 85
# Improved (102) Missing staff = 42 Late = 6 Late mins = 60
# Evals: 98
# Improved (97) Missing staff = 47 Late = 5 Late mins = 50
# Run 1 - Done: 97
#
# Run 2 - Init
# Initial best: 122
# Evals: 12
# Improved (121) Missing staff = 51 Late = 7 Late mins = 70
# Evals: 43
# Improved (118) Missing staff = 48 Late = 7 Late mins = 70
# Evals: 61
# Improved (116) Missing staff = 46 Late = 7 Late mins = 70
# Evals: 65
# Improved (115) Missing staff = 45 Late = 7 Late mins = 70
# Evals: 67
# Improved (114) Missing staff = 44 Late = 7 Late mins = 70
# Evals: 86
# Improved (113) Missing staff = 43 Late = 7 Late mins = 70
# Evals: 92
# Improved (109) Missing staff = 39 Late = 7 Late mins = 70
# Run 2 - Done: 109
#
# Run 3 - Init
# Initial best: 117
# Evals: 23
# Improved (109) Missing staff = 59 Late = 5 Late mins = 50
# Evals: 32
# Improved (108) Missing staff = 58 Late = 5 Late mins = 50
# Evals: 45
# Improved (106) Missing staff = 46 Late = 6 Late mins = 60
# Evals: 51
# Improved (102) Missing staff = 52 Late = 5 Late mins = 50
# Evals: 64
# Improved (97) Missing staff = 47 Late = 5 Late mins = 50
# Evals: 89
# Improved (96) Missing staff = 46 Late = 5 Late mins = 50
# Evals: 95
# Improved (92) Missing staff = 42 Late = 5 Late mins = 50
# Run 3 - Done: 92
#
# Run 4 - Init
# Initial best: 123
# Evals: 15
# Improved (117) Missing staff = 57 Late = 6 Late mins = 60
# Evals: 32
# Improved (114) Missing staff = 54 Late = 6 Late mins = 60
# Evals: 57
# Improved (113) Missing staff = 53 Late = 6 Late mins = 60
# Evals: 78
# Improved (110) Missing staff = 50 Late = 6 Late mins = 60
# Evals: 82
# Improved (107) Missing staff = 47 Late = 6 Late mins = 60
# Evals: 93
# Improved (98) Missing staff = 48 Late = 5 Late mins = 50
# Run 4 - Done: 98
#
# Run 5 - Init
# Initial best: 110
# Evals: 41
# Improved (101) Missing staff = 51 Late = 5 Late mins = 50
# Evals: 98
# Improved (94) Missing staff = 54 Late = 4 Late mins = 40
# Run 5 - Done: 94
#
# Running for aircrafts_sample_67 instance
# Run 1 - Init
# Initial best: 127
# Evals: 24
# Improved (126) Missing staff = 46 Late = 8 Late mins = 80
# Evals: 27
# Improved (117) Missing staff = 47 Late = 7 Late mins = 70
# Evals: 65
# Improved (109) Missing staff = 39 Late = 7 Late mins = 70
# Evals: 67
# Improved (96) Missing staff = 36 Late = 6 Late mins = 60
# Evals: 80
# Improved (94) Missing staff = 34 Late = 6 Late mins = 60
# Evals: 99
# Improved (93) Missing staff = 33 Late = 6 Late mins = 60
# Run 1 - Done: 93
#
# Run 2 - Init
# Initial best: 131
# Evals: 5
# Improved (125) Missing staff = 45 Late = 8 Late mins = 80
# Evals: 60
# Improved (111) Missing staff = 31 Late = 8 Late mins = 80
# Evals: 78
# Improved (110) Missing staff = 50 Late = 6 Late mins = 60
# Evals: 94
# Improved (101) Missing staff = 31 Late = 7 Late mins = 70
# Evals: 95
# Improved (95) Missing staff = 35 Late = 6 Late mins = 60
# Evals: 98
# Improved (94) Missing staff = 34 Late = 6 Late mins = 60
# Run 2 - Done: 94
#
# Run 3 - Init
# Initial best: 107
# Evals: 32
# Improved (106) Missing staff = 26 Late = 8 Late mins = 80
# Evals: 73
# Improved (104) Missing staff = 24 Late = 8 Late mins = 80
# Evals: 91
# Improved (98) Missing staff = 28 Late = 7 Late mins = 70
# Run 3 - Done: 98
#
# Run 4 - Init
# Initial best: 107
# Evals: 39
# Improved (106) Missing staff = 36 Late = 7 Late mins = 70
# Evals: 62
# Improved (103) Missing staff = 33 Late = 7 Late mins = 70
# Evals: 67
# Improved (101) Missing staff = 31 Late = 7 Late mins = 70
# Evals: 96
# Improved (100) Missing staff = 30 Late = 7 Late mins = 70
# Run 4 - Done: 100
#
# Run 5 - Init
# Initial best: 136
# Evals: 1
# Improved (134) Missing staff = 44 Late = 9 Late mins = 90
# Evals: 2
# Improved (127) Missing staff = 47 Late = 8 Late mins = 80
# Evals: 55
# Improved (125) Missing staff = 45 Late = 8 Late mins = 80
# Evals: 59
# Improved (124) Missing staff = 34 Late = 9 Late mins = 90
# Evals: 73
# Improved (118) Missing staff = 48 Late = 7 Late mins = 70
# Evals: 91
# Improved (110) Missing staff = 40 Late = 7 Late mins = 70
# Evals: 96
# Improved (109) Missing staff = 39 Late = 7 Late mins = 70
# Run 5 - Done: 109
#
# Running for aircrafts_instance_15 instance
# Run 1 - Init
# Initial best: 148
# Evals: 26
# Improved (143) Missing staff = 43 Late = 10 Late mins = 100
# Evals: 28
# Improved (139) Missing staff = 39 Late = 10 Late mins = 100
# Evals: 62
# Improved (133) Missing staff = 43 Late = 9 Late mins = 90
# Evals: 64
# Improved (119) Missing staff = 39 Late = 8 Late mins = 80
# Evals: 68
# Improved (115) Missing staff = 45 Late = 7 Late mins = 70
# Run 1 - Done: 115
#
# Run 2 - Init
# Initial best: 131
# Evals: 29
# Improved (120) Missing staff = 40 Late = 8 Late mins = 80
# Evals: 63
# Improved (119) Missing staff = 39 Late = 8 Late mins = 80
# Evals: 69
# Improved (113) Missing staff = 43 Late = 7 Late mins = 70
# Evals: 82
# Improved (112) Missing staff = 42 Late = 7 Late mins = 70
# Run 2 - Done: 112
#
# Run 3 - Init
# Initial best: 133
# Evals: 20
# Improved (123) Missing staff = 43 Late = 8 Late mins = 80
# Evals: 51
# Improved (122) Missing staff = 42 Late = 8 Late mins = 80
# Evals: 79
# Improved (108) Missing staff = 38 Late = 7 Late mins = 70
# Evals: 100
# Improved (107) Missing staff = 37 Late = 7 Late mins = 70
# Run 3 - Done: 107
#
# Run 4 - Init
# Initial best: 155
# Evals: 14
# Improved (147) Missing staff = 27 Late = 12 Late mins = 120
# Evals: 17
# Improved (146) Missing staff = 46 Late = 10 Late mins = 100
# Evals: 27
# Improved (145) Missing staff = 35 Late = 11 Late mins = 110
# Evals: 34
# Improved (143) Missing staff = 33 Late = 11 Late mins = 110
# Evals: 37
# Improved (141) Missing staff = 31 Late = 11 Late mins = 110
# Evals: 51
# Improved (140) Missing staff = 30 Late = 11 Late mins = 110
# Evals: 67
# Improved (139) Missing staff = 29 Late = 11 Late mins = 110
# Evals: 74
# Improved (131) Missing staff = 31 Late = 10 Late mins = 100
# Evals: 83
# Improved (130) Missing staff = 30 Late = 10 Late mins = 100
# Evals: 86
# Improved (129) Missing staff = 29 Late = 10 Late mins = 100
# Evals: 88
# Improved (128) Missing staff = 28 Late = 10 Late mins = 100
# Evals: 99
# Improved (119) Missing staff = 29 Late = 9 Late mins = 90
# Run 4 - Done: 119
#
# Run 5 - Init
# Initial best: 158
# Evals: 3
# Improved (153) Missing staff = 53 Late = 10 Late mins = 100
# Evals: 13
# Improved (151) Missing staff = 31 Late = 12 Late mins = 120
# Evals: 14
# Improved (145) Missing staff = 45 Late = 10 Late mins = 100
# Evals: 18
# Improved (140) Missing staff = 50 Late = 9 Late mins = 90
# Evals: 22
# Improved (136) Missing staff = 46 Late = 9 Late mins = 90
# Evals: 25
# Improved (134) Missing staff = 44 Late = 9 Late mins = 90
# Evals: 49
# Improved (129) Missing staff = 39 Late = 9 Late mins = 90
# Evals: 60
# Improved (127) Missing staff = 37 Late = 9 Late mins = 90
# Evals: 79
# Improved (126) Missing staff = 36 Late = 9 Late mins = 90
# Evals: 96
# Improved (125) Missing staff = 35 Late = 9 Late mins = 90
# Run 5 - Done: 125
#
# Running for aircrafts_instance_14 instance
# Run 1 - Init
# Initial best: 132
# Evals: 7
# Improved (122) Missing staff = 32 Late = 9 Late mins = 90
# Evals: 29
# Improved (115) Missing staff = 35 Late = 8 Late mins = 80
# Evals: 58
# Improved (105) Missing staff = 35 Late = 7 Late mins = 70
# Evals: 100
# Improved (99) Missing staff = 39 Late = 6 Late mins = 60
# Run 1 - Done: 99
#
# Run 2 - Init
# Initial best: 115
# Evals: 17
# Improved (114) Missing staff = 34 Late = 8 Late mins = 80
# Evals: 35
# Improved (100) Missing staff = 30 Late = 7 Late mins = 70
# Evals: 70
# Improved (96) Missing staff = 16 Late = 8 Late mins = 80
# Evals: 78
# Improved (93) Missing staff = 33 Late = 6 Late mins = 60
# Evals: 94
# Improved (90) Missing staff = 20 Late = 7 Late mins = 70
# Evals: 95
# Improved (89) Missing staff = 19 Late = 7 Late mins = 70
# Run 2 - Done: 89
#
# Run 3 - Init
# Initial best: 126
# Evals: 13
# Improved (108) Missing staff = 18 Late = 9 Late mins = 90
# Evals: 80
# Improved (107) Missing staff = 17 Late = 9 Late mins = 90
# Evals: 100
# Improved (106) Missing staff = 16 Late = 9 Late mins = 90
# Run 3 - Done: 106
#
# Run 4 - Init
# Initial best: 136
# Evals: 5
# Improved (126) Missing staff = 36 Late = 9 Late mins = 90
# Evals: 43
# Improved (125) Missing staff = 35 Late = 9 Late mins = 90
# Evals: 50
# Improved (124) Missing staff = 34 Late = 9 Late mins = 90
# Evals: 57
# Improved (112) Missing staff = 32 Late = 8 Late mins = 80
# Evals: 87
# Improved (111) Missing staff = 31 Late = 8 Late mins = 80
# Run 4 - Done: 111
#
# Run 5 - Init
# Initial best: 137
# Evals: 9
# Improved (128) Missing staff = 28 Late = 10 Late mins = 100
# Evals: 15
# Improved (127) Missing staff = 27 Late = 10 Late mins = 100
# Evals: 18
# Improved (121) Missing staff = 21 Late = 10 Late mins = 100
# Evals: 23
# Improved (115) Missing staff = 25 Late = 9 Late mins = 90
# Evals: 25
# Improved (104) Missing staff = 24 Late = 8 Late mins = 80
# Evals: 30
# Improved (103) Missing staff = 23 Late = 8 Late mins = 80
# Evals: 34
# Improved (98) Missing staff = 28 Late = 7 Late mins = 70
# Evals: 85
# Improved (93) Missing staff = 23 Late = 7 Late mins = 70
# Run 5 - Done: 93
#
# Running for aircrafts_sample_66 instance
# Run 1 - Init
# Initial best: 67
# Evals: 6
# Improved (61) Missing staff = 31 Late = 3 Late mins = 30
# Evals: 24
# Improved (60) Missing staff = 30 Late = 3 Late mins = 30
# Evals: 59
# Improved (59) Missing staff = 29 Late = 3 Late mins = 30
# Evals: 75
# Improved (49) Missing staff = 29 Late = 2 Late mins = 20
# Evals: 83
# Improved (47) Missing staff = 27 Late = 2 Late mins = 20
# Evals: 90
# Improved (46) Missing staff = 26 Late = 2 Late mins = 20
# Run 1 - Done: 46
#
# Run 2 - Init
# Initial best: 69
# Evals: 23
# Improved (48) Missing staff = 28 Late = 2 Late mins = 20
# Evals: 31
# Improved (47) Missing staff = 27 Late = 2 Late mins = 20
# Evals: 45
# Improved (46) Missing staff = 26 Late = 2 Late mins = 20
# Evals: 54
# Improved (45) Missing staff = 25 Late = 2 Late mins = 20
# Evals: 85
# Improved (44) Missing staff = 24 Late = 2 Late mins = 20
# Evals: 97
# Improved (31) Missing staff = 21 Late = 1 Late mins = 10
# Run 2 - Done: 31
#
# Run 3 - Init
# Initial best: 72
# Evals: 12
# Improved (70) Missing staff = 30 Late = 4 Late mins = 40
# Evals: 16
# Improved (62) Missing staff = 32 Late = 3 Late mins = 30
# Evals: 54
# Improved (61) Missing staff = 31 Late = 3 Late mins = 30
# Evals: 63
# Improved (60) Missing staff = 30 Late = 3 Late mins = 30
# Evals: 75
# Improved (55) Missing staff = 35 Late = 2 Late mins = 20
# Evals: 81
# Improved (54) Missing staff = 34 Late = 2 Late mins = 20
# Evals: 82
# Improved (52) Missing staff = 32 Late = 2 Late mins = 20
# Evals: 93
# Improved (50) Missing staff = 30 Late = 2 Late mins = 20
# Evals: 97
# Improved (44) Missing staff = 24 Late = 2 Late mins = 20
# Run 3 - Done: 44
#
# Run 4 - Init
# Initial best: 73
# Evals: 4
# Improved (70) Missing staff = 30 Late = 4 Late mins = 40
# Evals: 53
# Improved (69) Missing staff = 29 Late = 4 Late mins = 40
# Run 4 - Done: 69
#
# Run 5 - Init
# Initial best: 85
# Evals: 3
# Improved (81) Missing staff = 41 Late = 4 Late mins = 40
# Evals: 12
# Improved (76) Missing staff = 46 Late = 3 Late mins = 30
# Evals: 14
# Improved (70) Missing staff = 40 Late = 3 Late mins = 30
# Evals: 87
# Improved (63) Missing staff = 53 Late = 1 Late mins = 10
# Run 5 - Done: 63
#
# Running for aircrafts_sample_72 instance
# Run 1 - Init
# Initial best: 110
# Evals: 13
# Improved (109) Missing staff = 29 Late = 8 Late mins = 80
# Evals: 24
# Improved (99) Missing staff = 29 Late = 7 Late mins = 70
# Evals: 58
# Improved (98) Missing staff = 28 Late = 7 Late mins = 70
# Evals: 60
# Improved (87) Missing staff = 27 Late = 6 Late mins = 60
# Evals: 63
# Improved (86) Missing staff = 26 Late = 6 Late mins = 60
# Evals: 80
# Improved (78) Missing staff = 28 Late = 5 Late mins = 50
# Evals: 86
# Improved (77) Missing staff = 27 Late = 5 Late mins = 50
# Evals: 88
# Improved (74) Missing staff = 24 Late = 5 Late mins = 50
# Run 1 - Done: 74
#
# Run 2 - Init
# Initial best: 125
# Evals: 2
# Improved (115) Missing staff = 35 Late = 8 Late mins = 80
# Evals: 33
# Improved (113) Missing staff = 33 Late = 8 Late mins = 80
# Evals: 62
# Improved (112) Missing staff = 32 Late = 8 Late mins = 80
# Evals: 67
# Improved (108) Missing staff = 38 Late = 7 Late mins = 70
# Evals: 81
# Improved (101) Missing staff = 31 Late = 7 Late mins = 70
# Evals: 100
# Improved (99) Missing staff = 39 Late = 6 Late mins = 60
# Run 2 - Done: 99
#
# Run 3 - Init
# Initial best: 110
# Evals: 11
# Improved (105) Missing staff = 35 Late = 7 Late mins = 70
# Evals: 62
# Improved (97) Missing staff = 37 Late = 6 Late mins = 60
# Evals: 74
# Improved (95) Missing staff = 35 Late = 6 Late mins = 60
# Evals: 76
# Improved (90) Missing staff = 40 Late = 5 Late mins = 50
# Evals: 94
# Improved (85) Missing staff = 35 Late = 5 Late mins = 50
# Run 3 - Done: 85
#
# Run 4 - Init
# Initial best: 122
# Evals: 1
# Improved (116) Missing staff = 36 Late = 8 Late mins = 80
# Evals: 46
# Improved (107) Missing staff = 37 Late = 7 Late mins = 70
# Evals: 54
# Improved (106) Missing staff = 36 Late = 7 Late mins = 70
# Evals: 58
# Improved (96) Missing staff = 36 Late = 6 Late mins = 60
# Evals: 71
# Improved (93) Missing staff = 33 Late = 6 Late mins = 60
# Run 4 - Done: 93
#
# Run 5 - Init
# Initial best: 111
# Evals: 17
# Improved (109) Missing staff = 29 Late = 8 Late mins = 80
# Evals: 27
# Improved (102) Missing staff = 32 Late = 7 Late mins = 70
# Evals: 52
# Improved (101) Missing staff = 31 Late = 7 Late mins = 70
# Run 5 - Done: 101
#
# Average fitness over 10 runs: Math Method 90.4 and Numpy Method 90.4
# Standard Deviation: 9.911609354691095
